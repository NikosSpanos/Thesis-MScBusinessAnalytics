# %% [markdown]
# #### Import the libraries

# %%
# For cleaning and preparing the dataset
# -> dataframe manipulation
# -> text manipulation
# -> Web Scrapping

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re


# Module to serialize the content produced from the execution of the code

import pickle


# Module to monitor the progress of a python for loop

from tqdm import tqdm


# Module to manipulate text in python - NLTK package

import nltk
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords


# Module to compute word vectorizers and compute the cosine distance

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_distances

# %% [markdown]
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# #### Import the dataset

# %%
dataset = pd.read_pickle('D:\\GitHub-Thesis\\58,000 movies\\final_dataset_49393_movies_25012020.pkl') 

#previous versions "final_dataset_07112019", "final_dataset_22102019.pkl", dataset_part_1_17112019.pkl

dataset = dataset.reset_index(drop=True)

# %%
#dataset = dataset.join(pd.DataFrame(dataset.Genres.values.tolist(), dataset.index).add_prefix('Genres_').fillna(0)) old versions

# %%
#dataset = dataset.drop(['Genres_3', 'Genres_4', 'Genres_5', 'Genres_6', 'Genres_7', 'Genres_8'], axis=1) old versions

# %%
dataset.head()

# %% [markdown]
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# #### Cleaning the columns

# %% [markdown]
# ##### Movie Title (25.10.2019)

# %% [markdown]
# ##### Step 1: Clean the year (i.e 2001) from each title - 25.10.2019

# %%
exp = r'\(\d\d\d\d.'

dataset['title'] = dataset['title'].apply(lambda x: re.sub(exp,"",x).strip())

# %%
# dataset['title'] = dataset['title'].apply(lambda x: x.replace(',', ''))

# %%
dataset.head()
# Out:
#                          title                            genres  rating  \
# 0                    Toy Story  [Adventure, Animation, Children]    3.89
# 1                      Jumanji    [Adventure, Children, Fantasy]    3.25
# 2             Grumpier Old Men                 [Comedy, Romance]    3.17
# 3            Waiting to Exhale          [Comedy, Drama, Romance]    2.87
# 4  Father of the Bride Part II                          [Comedy]    3.08
#
#                                imdb_url  \
# 0  http://www.imdb.com/title/tt0114709/
# 1  http://www.imdb.com/title/tt0113497/
# 2  http://www.imdb.com/title/tt0113228/
# 3  http://www.imdb.com/title/tt0114885/
# 4  http://www.imdb.com/title/tt0113041/
#
#                                          reviews_url  \
# 0  http://www.imdb.com/title/tt0114709/reviews?sp...
# 1  http://www.imdb.com/title/tt0113497/reviews?sp...
# 2  http://www.imdb.com/title/tt0113228/reviews?sp...
# 3  http://www.imdb.com/title/tt0114885/reviews?sp...
# 4  http://www.imdb.com/title/tt0113041/reviews?sp...
#
#                                               actors  \
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Sophia Loren, An...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                                                 plot imdb_rating  \
# 0  \n                    A cowboy doll is profoun...         8.3
# 1  \n                    When two kids find and p...         7.0
# 2  \n                    John and Max resolve to ...         6.7
# 3  \n                    Based on Terry McMillan'...         5.9
# 4  \n                    George Banks must deal n...         6.0
#
#           director                                            reviews
# 0    John Lasseter  [Andy's toys live a reasonable life of fun and...
# 1     Joe Johnston  [The smash hit 1995 film Jumanji- based on the...
# 2    Howard Deutch  [Sequels are rarely half as good as the origin...
# 3  Forest Whitaker  [I read some of the other comments comcerning ...
# 4    Charles Shyer  [I enjoyed this film, as I did Father of the B...

# %% [markdown]
# ##### Step 2: Replace (,The) & (,A) from the end of the string, at the front - 26.01.2020

# %%
dataset[dataset.director == "Guido Zurli"]
# Out:
#                         title           genres  rating  \
# 29885  Bersaglio altezza uomo         [Action]     2.0
# 29886         The Mad Butcher         [Horror]     2.0
# 29887              Psychopath  [Comedy, Crime]     2.5
# 29888           Thompson 1880        [Western]     0.0
#
#                                    imdb_url  \
# 29885  http://www.imdb.com/title/tt0078848/
# 29886  http://www.imdb.com/title/tt0067799/
# 29887  http://www.imdb.com/title/tt0061983/
# 29888  http://www.imdb.com/title/tt0061090/
#
#                                              reviews_url  \
# 29885  http://www.imdb.com/title/tt0078848/reviews?sp...
# 29886  http://www.imdb.com/title/tt0067799/reviews?sp...
# 29887  http://www.imdb.com/title/tt0061983/reviews?sp...
# 29888  http://www.imdb.com/title/tt0061090/reviews?sp...
#
#                                                   actors  \
# 29885  [Luc Merenda, Gabriella Giorgelli, Kadir Inani...
# 29886  [Victor Buono, Franca Polesello, Brad Harris, ...
# 29887  [George Martin, Ingrid Schoeller, Karin Field,...
# 29888  [George Martin, Gia Sandri, José Bódalo, Osiri...
#
#                                                     plot imdb_rating  \
# 29885                       \nAdd a Plot »\n                     5.5
# 29886  \n                    After being released fro...         5.3
# 29887  \n                    The hero steals the haul...         5.0
# 29888                       \nAdd a Plot »\n                     6.3
#
#           director                                            reviews
# 29885  Guido Zurli  [This is surely one of the lamest poliziottesc...
# 29886  Guido Zurli  [When formerly respected local butcher Otto Le...
# 29887  Guido Zurli  [Little role for Klaus Kinski but funny, he's ...
# 29888  Guido Zurli  [A western made during the boom of such movies...

# %% [markdown]
# #### Comment: As we can see two of the above titles have the inconcistencies mentioned. Thus, they should be fixed.

# %%
dataset_test_sql = dataset.iloc[0:1810]

dataset_test_sql.shape
# Out:
# (1810, 10)

# %%
def move_word(s, word, pos):
    split = s.split(',')
    if "The" in split:
        print(s)
        #split = s.split()
        split.insert(pos, split.pop(split.index(word)))
        print(split)
        return ' '.join(split)
    else:
        print(s)
        return ' '.join(split)

# %%
def reorder(s, word, delta):
    words = s.split()
    oldpos = words.index(word)
    words.insert(oldpos+delta, words.pop(oldpos))
    return ' '.join(words)

# %%
# Dummy test dataset

# dataset_test_sql.title = dataset_test_sql.title.apply(lambda x: move_word(x, ' The', 0))

# dataset_test_sql.title = dataset_test_sql.title.apply(lambda x: move_word(x, ' A', 0))


# ------------------------------------------

# Replace (,The)
dataset_test_sql['title'].apply(lambda x: move_word(x, ' The', 0))
# Out:
# Toy Story
# Jumanji
# Grumpier Old Men
# Waiting to Exhale
# Father of the Bride Part II
# Heat
# Sabrina
# Tom and Huck
# Sudden Death
# GoldenEye
#  TheAmerican President
# Dracula: Dead and Loving It
# Balto
# Nixon
# Cutthroat Island
# Casino
# Sense and Sensibility
# Four Rooms
# Ace Ventura: When Nature Calls
# Money Train
# Get Shorty
# Copycat
# Assassins
# Powder
# Leaving Las Vegas
# Othello
# Now and Then
# Persuasion
# City of Lost Children The (Cité des enfants perdus La)
# Shanghai Triad (Yao a yao yao dao waipo qiao)
# Dangerous Minds
# Twelve Monkeys (a.k.a. 12 Monkeys)
# Wings of Courage
# Babe
# Carrington
# Dead Man Walking
# Across the Sea of Time
# It Takes Two
# Clueless
# Cry the Beloved Country
# Richard III
# Dead Presidents
# Restoration
# Mortal Kombat
# To Die For
# How to Make an American Quilt
# Seven (a.k.a. Se7en)
# Pocahontas
# When Night Is Falling
#  TheUsual Suspects
# Guardian Angel
# Mighty Aphrodite
# Lamerica
#  TheBig Green
# Georgia
# Kids of the Round Table
# Home for the Holidays
# Postman The (Postino Il)
# Confessional The (Confessionnal Le)
#  TheIndian in the Cupboard
# Eye for an Eye
# Mr. Holland's Opus
# Don't Be a Menace to South Central While Drinking Your Juice in the Hood
# Two if by Sea
# Bio-Dome
# Lawnmower Man 2: Beyond Cyberspace
# Two Bits
# French Twist (Gazon maudit)
# Friday
# From Dusk Till Dawn
# Fair Game
# Kicking and Screaming
# Misérables Les
# Bed of Roses
# Big Bully
# Screamers
# Nico Icon
#  TheCrossing Guard
#  TheJuror
# White Balloon The (Badkonake sefid)
# Things to Do in Denver When You're Dead
# Antonia's Line (Antonia)
# Once Upon a Time... When We Were Colored
# Last Summer in the Hamptons
# Angels and Insects
# White Squall
# Dunston Checks In
# Black Sheep
# Nick of Time
# The Journey of August King
# Mary Reilly
# Vampire in Brooklyn
# Beautiful Girls
# Broken Arrow
# In the Bleak Midwinter
# Hate (Haine La)
# Shopping
# Heidi Fleiss: Hollywood Madam
# City Hall
# Bottle Rocket
# Mr. Wrong
# Unforgettable
# Happy Gilmore
#  TheBridges of Madison County
# Nobody Loves Me (Keiner liebt mich)
# Muppet Treasure Island
# Catwalk
# Headless Body in Topless Bar
# Braveheart
# Taxi Driver
# Rumble in the Bronx (Hont faan kui)
# Before and After
# Margaret's Museum
# Happiness Is in the Field (Bonheur est dans le pré Le)
# Anne Frank Remembered
#  TheYoung Poisoner's Handbook
# If Lucy Fell
# Steal Big Steal Little
# Race the Sun
#  TheBoys of St. Vincent
# Boomerang
# Chungking Express (Chung Hing sam lam)
# Star Maker The (Uomo delle stelle L')
# Flirting With Disaster
#  TheNeverEnding Story III
# Silences of the Palace The (Saimt el Qusur)
# Jupiter's Wife
# Pie in the Sky
# Angela
# Frankie Starlight
# Jade
# Nueba Yol
# Sonic Outlaws
# Down Periscope
# From the Journals of Jean Seberg
# Man of the Year
#  TheNeon Bible
# Up Close and Personal
#  TheBirdcage
# Shadows (Cienie)
# Gospa
#  TheBrothers McMullen
# Bad Boys
#  TheAmazing Panda Adventure
#  TheBasketball Diaries
# Awfully Big Adventure An
# Amateur
# Apollo 13
# Rob Roy
#  TheAddiction
# Batman Forever
# Beauty of the Day (Belle de jour)
# Beyond Rangoon
# Blue in the Face
# Canadian Bacon
# Casper
# Clockers
# Congo
# Crimson Tide
# Crumb
# Desperado
# Devil in a Blue Dress
# Die Hard: With a Vengeance
# Three Colors: Blue (Trois couleurs: Bleu)
# Three Colors: White (Trzy kolory: Bialy)
# Red Firecracker Green Firecracker (Pao Da Shuang Deng)
# Rent-a-Kid
# Relative Fear
# Stuart Saves His Family
#  TheSwan Princess
#  TheSecret of Roan Inish
#  TheSpecialist
# Stargate
#  TheSanta Clause
#  TheShawshank Redemption
# Shallow Grave
# Suture
# Strawberry and Chocolate (Fresa y chocolate)
# Swimming with Sharks
#  TheSum of Us
# National Lampoon's Senior Trip
# To Live (Huozhe)
# Tank Girl
# Tales from the Crypt Presents: Demon Knight
# Star Trek: Generations
# Tales from the Hood
# Tom & Viv
# Village of the Damned
# Tommy Boy
# Vanya on 42nd Street
# Underneath
#  TheWalking Dead
# What's Eating Gilbert Grape
# Virtuosity
# While You Were Sleeping
#  TheWar
# Double Happiness
# Muriel's Wedding
#  TheBaby-Sitters Club
# Ace Ventura: Pet Detective
#  TheAdventures of Priscilla Queen of the Desert
# Backbeat
# Bitter Moon
# Bullets Over Broadway
# Clear and Present Danger
#  TheClient
# Corrina Corrina
# Crooklyn
#  TheCrow
# Cobb
#  TheFlintstones
# Forrest Gump
# Four Weddings and a Funeral
# Higher Learning
# I Like It Like That
# I Love Trouble
# It Could Happen to You
#  TheJungle Book
# Wonderful Horrible Life of Leni Riefenstahl The (Macht der Bilder: Leni Riefenstahl Die)
#  TheLion King
# Little Buddha
# Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale A)
#  TheMask
# Maverick
# Mrs. Parker and the Vicious Circle
# Naked Gun 33 1/3: The Final Insult
#  ThePaper
# Reality Bites
# Red Rock West
# Richie Rich
# Safe Passage
#  TheRiver Wild
# Speed
# Speechless
# Timecop
# True Lies
# When a Man Loves a Woman
# Wolf
# Wyatt Earp
# Bad Company
# Man of No Importance A
# S.F.W.
# Low Down Dirty Shame A
# Boys Life
# Colonel Chabert Le
# Faster Pussycat! Kill! Kill!
# Jason's Lyric
#  TheSecret Adventures of Tom Thumb
# Street Fighter
# Coldblooded
# Desert Winds
# Fall Time
#  TheFear
# Frank and Ollie
# Girl in the Cadillac
# Homage
# Mirage
# Open Season
# Two Crimes (Dos crímenes)
# Brother Minister: The Assassination of Malcolm X
# Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension)
# Federal Hill
# In the Mouth of Madness
# 8 Seconds
# Above the Rim
# Addams Family Values
# Martin Lawrence: You So Crazy
#  TheAge of Innocence
# Airheads
#  TheAir Up There
# Another Stakeout
# Bad Girls
# Barcelona
# Being Human
#  TheBeverly Hillbillies
# Beverly Hills Cop III
# Black Beauty
# Blink
# Blown Away
# Blue Chips
# Blue Sky
# Body Snatchers
# Boxing Helena
# Bronx Tale A
# Cabin Boy
# Calendar Girl
# Carlito's Way
# City Slickers II: The Legend of Curly's Gold
# Clean Slate
# Cliffhanger
# Coneheads
# Color of Night
# Cops and Robbersons
#  TheCowboy Way
# Dangerous Game
# Dave
# Dazed and Confused
# Demolition Man
#  TheEndless Summer 2
# Even Cowgirls Get the Blues
# Fatal Instinct
# Farewell My Concubine (Ba wang bie ji)
#  TheFavor
# Fearless
#  TheWild Bunch
# Love and a .45
# Wooden Man's Bride The (Yan shen)
# Great Day in Harlem A
# Bye Bye Love
# One Fine Day
# Candyman: Farewell to the Flesh
# Century
# Fargo
# Homeward Bound II: Lost in San Francisco
# Heavy Metal
# Hellraiser: Bloodline
#  ThePallbearer
# Jane Eyre
# Loaded
# Bread and Chocolate (Pane e cioccolata)
#  TheAristocats
# Flower of My Secret The (La flor de mi secreto)
# Two Much
# Ed
# Scream of Stone (Cerro Torre: Schrei aus Stein)
# My Favorite Season
# Modern Affair A
# Condition Red (Beyond the Law)
# Asfour Stah
# Thin Line Between Love and Hate A
#  TheLast Supper
# Primal Fear
# Rude
# Carried Away
# All Dogs Go to Heaven 2
# Land and Freedom (Tierra y libertad)
# Denise Calls Up
# Theodore Rex
# Family Thing A
# Frisk
# Sgt. Bilko
# Jack and Sarah
# Girl 6
# Diabolique
# Little Indian Big City (Un indien dans la ville)
# Nelly & Monsieur Arnaud
# Courage Under Fire
# Mission: Impossible
# Cold Fever (Á köldum klaka)
# Moll Flanders
# Superweib Das
# 301 302 (301/302)
# Dragonheart
# My Mother's Courage (Mutters Courage)
# Eddie
# Yankee Zulu
# Billy's Holiday
# Purple Noon (Plein soleil)
# August
# James and the Giant Peach
# Fear
# Kids in the Hall: Brain Candy
# Faithful
# Underground
# All Things Fair (Lust och fägring stor)
# Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite)
# Song of the Little Road (Pather Panchali)
# World of Apu The (Apur Sansar)
# Mystery Science Theater 3000: The Movie
# Space Jam
# Barbarella
# Hostile Intentions
# They Bite
# Some Folks Call It a Sling Blade
#  TheRun of the Country
# Alphaville (Alphaville une étrange aventure de Lemmy Caution)
# Coup de torchon (Clean Slate)
# Tigrero: A Film That Was Never Made
# Eye of Vichy The (Oeil de Vichy L')
# Windows
# It's My Party
# Country Life
# Operation Dumbo Drop
# Promise The (Versprechen Das)
# Mrs. Winterbourne
# Solo
# Under the Domim Tree (Etz Hadomim Tafus)
#  TheSubstitute
# True Crime
# Butterfly Kiss
# Feeling Minnesota
# Delta of Venus
# To Cross the Rubicon
# Angus
# Daens
# Faces
# Boys
#  TheQuest
# Cosi
# Sunset Park
# Mulholland Falls
#  TheTruth About Cats & Dogs
# Oliver & Company
# Celtic Pride
# Flipper
# Captives
# Of Love and Shadows
# Dead Man
# Horseman on the Roof The (Hussard sur le toit Le)
# Switchblade Sisters
# Mouth to Mouth (Boca a boca)
# Visitors The (Visiteurs Les)
# Multiplicity
# Halfmoon (Paul Bowles - Halbmond)
#  TheHaunted World of Edward D. Wood Jr.
# Two Friends
#  TheCraft
#  TheGreat White Hype
# Last Dance
# War Stories
# Original Gangstas
#  TheRock
# Getting Away With Murder
# Cemetery Man (Dellamorte Dellamore)
# Twister
# Barb Wire
# Ghost in the Shell (Kôkaku kidôtai)
# Thinner
# Wallace & Gromit: A Close Shave
# Force of Evil
#  TheStupids
#  TheArrival
#  TheMan from Down Under
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# Vermont Is For Lovers
# Month by the Lake A
# Gold Diggers: The Secret of Bear Mountain
# Kim
# Carmen Miranda: Bananas Is My Business
# Ashes of Time (Dung che sai duk)
# Jar The (Khomreh)
# Maya Lin: A Strong Clear Vision
# Stalingrad
#  ThePhantom
# Striptease
# Last of the High Kings The (a.k.a. Summer Fling)
# Heavy
# Jack
# I Shot Andy Warhol
#  TheGrass Harp
# Life Is Rosy (a.k.a. Life Is Beautiful) (Vie est belle La)
# Quartier Mozart
# Touki Bouki
# Wend Kuuni (a.k.a. God's Gift)
# Spirits of the Dead
# Babyfever
# Pharaoh's Army
# Trainspotting
# 'Til There Was You
# Independence Day (a.k.a. ID4)
# Stealing Beauty
#  TheFan
#  TheHunchback of Notre Dame
#  TheCable Guy
# Kingpin
#  TheNutty Professor
# I the Worst of All (Yo la peor de todas)
#  TheLast Klezmer: Leopold Kozlowski His Life and Music
# Hungarian Fairy Tale A (Hol volt hol nem volt)
# My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud)
# Midnight Dancers (Sibak)
# Somebody to Love
# Very Natural Thing A
# Old Lady Who Walked in the Sea The (Vieille qui marchait dans la mer La)
# Daylight
#  TheFrighteners
# Lone Star
# Harriet the Spy
# Phenomenon
# Walking and Talking
# She's the One
# American Buffalo
# Rendezvous in Paris (Rendez-vous de Paris Les)
# Alaska
# Fled
# Kazaam
# Magic Hunter (Büvös vadász)
# Larger Than Life
# Boy Called Hate A
# Power 98
# Two Deaths
# Very Brady Sequel A
# Stefano Quantestorie
# Death in the Garden (Mort en ce jardin La)
#  TheCrude Oasis
# Hedd Wyn
# Collector The (La collectionneuse)
# Kaspar Hauser
# Convent The (O Convento)
#  TheAdventures of Pinocchio
# Joe's Apartment
#  TheFirst Wives Club
# Stonewall
# Ransom
# High School High
# Phat Beach
# Foxfire
# Chain Reaction
# Matilda
# Emma
# House Arrest
# Eyes Without a Face (Yeux sans visage Les)
# Tales from the Crypt Presents: Bordello of Blood
# Lotto Land
# Story of Xinghua The (Xinghua san yue tian)
# Day the Sun Turned Cold The (Tianguo niezi)
# Flirt
#  TheBig Squeeze
#  TheSpitfire Grill
# Escape from L.A.
# Cyclo (Xich lo)
# Tin Cup
# Dingo
# Ballad of Narayama The (Narayama Bushiko)
# Every Other Weekend (Un week-end sur deux)
# Mille bolle blu
# Crows and Sparrows (Wuya yu maque)
# Maybe Maybe Not (Bewegte Mann Der)
# Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha)
# Manny & Lo
#  TheWife
# Small Faces
# Bound
# Carpool
# Death in Brunswick
# Kansas City
# Gone Fishin'
# Lover's Knot
# Killer: A Journal of Murder
# Nothing to Lose
# Supercop 2 (Project S) (Chao ji ji hua)
# Girls Town
# Bye-Bye
#  TheRelic
#  TheIsland of Dr. Moreau
# First Kid
#  TheTrigger Effect
# Sweet Nothing
# Bogus
# Bulletproof
# Talk of Angels
# Land Before Time III: The Time of the Great Giving
# 1-900 (06)
# Baton Rouge (Bâton rouge)
# Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael My
#  TheLong Kiss Goodnight
#  TheGhost and the Darkness
# Looking for Richard
# Trees Lounge
#  TheProprietor
# Normal Life
# Get on the Bus
# Shadow Conspiracy
# Jude
# Everyone Says I Love You
# Bitter Sugar (Azúcar amarga)
# William Shakespeare's Romeo + Juliet
# Swingers
# Sleepers
#  TheSunchaser
# Johns
# Aladdin and the King of Thieves
# Five Angles on Murder
# Shall We Dance
# Damsel in Distress A
# Crossfire
# Murder My Sweet
# Macao
# For the Moment
# Willy Wonka & the Chocolate Factory
# Sexual Life of the Belgians The (Vie sexuelle des Belges 1950-1978 La)
#  TheInnocents
# Sleeper
# Bananas
# Fish Called Wanda A
# Monty Python's Life of Brian
# Victor/Victoria
#  TheCandidate
#  TheGreat Race
# Bonnie and Clyde
# Dial M for Murder
# Madame Butterfly
# Dirty Dancing
# Reservoir Dogs
# Platoon
# Weekend at Bernie's
# Basic Instinct
#  TheDoors
#  TheCrying Game
# Glengarry Glen Ross
# Sophie's Choice
# E.T. the Extra-Terrestrial
#  TheSearch for One-eye Jimmy
# Christmas Carol A
# Days of Thunder
# Top Gun
# American Strays
# Rebel Without a Cause
# Streetcar Named Desire A
# Children of the Corn IV: The Gathering
#  TheLeopard Son
# Bird of Prey
# Microcosmos (Microcosmos: Le peuple de l'herbe)
# Palookaville
#  TheAssociate
#  TheFuneral
# Sleepover
# Eighth Day The (Huitième jour Le)
# Drunks
#  ThePeople vs. Larry Flynt
# Glory Daze
# Plutonium Circus
# Perfect Candidate A
# On Golden Pond
#  TheReturn of the Pink Panther
# Drop Dead Fred
#  TheFog
# Escape from New York
#  TheHowling
# Jean de Florette
# Johnny 100 Pesos (Johnny cien pesos)
# Private Benjamin
# Monty Python and the Holy Grail
# Dadetown
# Everything Relative
# Three Lives and Only One Death (Trois vies & une seule mort)
# Curtis's Charm
# When We Were Kings
# Wallace & Gromit: The Wrong Trousers
# JLG/JLG (JLG/JLG - autoportrait de décembre)
# Return of Martin Guerre The (Retour de Martin Guerre Le)
# Lesson Faust
# He Walked by Night
# Raw Deal
# Children Are Watching Us The (Bambini ci guardano I)
# Symphonie pastorale La
# Here Comes Cookie
# Love in Bloom
# Six of a Kind
# Tin Drum The (Blechtrommel Die)
#  TheRuling Class
# Mina Tannenbaum
# 2 ou 3 choses que je sais d'elle (2 or 3 Things I Know About Her)
# Dear God
# Bad Moon
# American Dream
# Best of the Best 3: No Turning Back
# Bob Roberts
# Cinema Paradiso (Nuovo cinema Paradiso)
#  TheCook the Thief His Wife & Her Lover
# Dead Tired (Grosse Fatigue)
# Delicatessen
# Double Life of Veronique The (Double Vie de Véronique La)
# Enchanted April
# Paths of Glory
#  TheGrifters
# Hear My Song
#  TheShooter
#  TheEnglish Patient
# Mediterraneo
# My Left Foot
# Sex Lies and Videotape
# Passion Fish
# Strictly Ballroom
#  TheThin Blue Line
# Tie Me Up! Tie Me Down! (¡Átame!)
# Madonna: Truth or Dare
# Paris Is Burning
# One Flew Over the Cuckoo's Nest
# Cheech and Chong's Up in Smoke
# Star Wars: Episode V - The Empire Strikes Back
#  ThePrincess Bride
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark)
# Brazil
# Aliens
# Good the Bad and the Ugly The (Buono il brutto il cattivo Il)
# Withnail & I
# 12 Angry Men
# Lawrence of Arabia
# Clockwork Orange A
# To Kill a Mockingbird
# Apocalypse Now
# Once Upon a Time in the West (C'era una volta il West)
# Star Wars: Episode VI - Return of the Jedi
# Wings of Desire (Himmel über Berlin Der)
#  TheThird Man
# Goodfellas
# Alien
# Army of Darkness
# Big Blue The (Grand bleu Le)
# Ran
# Killer The (Die xue shuang xiong)
# Psycho
#  TheBlues Brothers
#  TheGodfather: Part II
# Full Metal Jacket
# Grand Day Out with Wallace and Gromit A
# Henry V
# Amadeus
#  TheQuiet Man
# Once Upon a Time in America
# Raging Bull
# Annie Hall
#  TheRight Stuff
# Stalker
# Boot Das (Boat The)
#  TheSting
# Harold and Maude
# Trust
# Seventh Seal The (Sjunde inseglet Det)
# Local Hero
#  TheTerminator
# Dead Alive (Braindead)
# Glory
# Rosencrantz and Guildenstern Are Dead
# Manhattan
# Miller's Crossing
# Dead Poets Society
#  TheGraduate
# Touch of Evil
# Femme Nikita La (Nikita)
#  TheBridge on the River Kwai
# 8 1/2 (8½)
# Chinatown
#  TheDay the Earth Stood Still
#  TheTreasure of the Sierra Madre
# Bad Taste
# Duck Soup
# Better Off Dead...
#  TheShining
# Stand by Me
# M
# Evil Dead II (Dead by Dawn)
#  TheGreat Escape
#  TheDeer Hunter
# Diva
# Groundhog Day
# Unforgiven
#  TheManchurian Candidate
# Pump Up the Volume
# Arsenic and Old Lace
# Back to the Future
# Fried Green Tomatoes
# Patton
# Down by Law
# Akira
# Highlander
# Cool Hand Luke
# Cyrano de Bergerac
# Young Frankenstein
# Night on Earth
# Raise the Red Lantern (Da hong deng long gao gao gua)
#  TheGreat Dictator
# Fantasia
# High Noon
#  TheBig Sleep
# Heathers
# Ben-Hur
# This Is Spinal Tap
# Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance)
# Some Kind of Wonderful
# Indiana Jones and the Last Crusade
# Being There
# Gandhi
#  TheUnbearable Lightness of Being
# Room with a View A
# Real Genius
# Pink Floyd: The Wall
#  TheKilling Fields
# My Life as a Dog (Mitt liv som hund)
# Forbidden Planet
# Field of Dreams
#  TheMan Who Would Be King
# Butch Cassidy and the Sundance Kid
# Paris Texas
# Until the End of the World (Bis ans Ende der Welt)
# When Harry Met Sally...
# I Shot a Man in Vegas
# Parallel Sons
# Hype!
# Santa with Muscles
# Female Perversions
# Mad Dog Time
# Breathing Room
# I'm Not Rappaport
# Alien³ (a.k.a. Alien 3)
# American Werewolf in London An
# Amityville 1992: It's About Time
# Amityville 3-D
# Amityville: Dollhouse
# Amityville: A New Generation
# Amityville II: The Possession
#  TheAmityville Horror
#  TheAmityville Curse
# Blood for Dracula (Andy Warhol's Dracula)
# April Fool's Day
# Audrey Rose
#  TheBelievers
#  TheBirds
#  TheBlob
# Blood Beach
# Body Parts
#  TheBody Snatcher
# Anna Karenina
# Double Team
# Inventing the Abbotts
# Anaconda
# Grosse Pointe Blank
# Keys to Tulsa
# Kissed
# 8 Heads in a Duffel Bag
# Hollow Reed
# Paradise Road
# Traveller
# All Over Me
# Brother's Kiss A
# Chef in Love A (Shekvarebuli kulinaris ataserti retsepti)
# Romy and Michele's High School Reunion
# Temptress Moon (Feng Yue)
# Volcano
# Children of the Revolution
# Austin Powers: International Man of Mystery
# Breakdown
# Broken English
# Commandments
# Ripe
# Truth or Consequences N.M.
#  TheTurning
# Warriors of Virtue
# Fathers' Day
#  TheFifth Element
# Intimate Relations
# Nowhere
# Losing Chase
# Sprung
# Promise The (La promesse)
# Bonheur Le
# Love! Valour! Compassion!
# Shall We Dance? (Shall We Dansu?)
#  TheSecond Jungle Book: Mowgli & Baloo
# Twin Town
# Addicted to Love
# Brassed Off
#  TheDesignated Mourner
#  TheLost World: Jurassic Park
# Ponette
# Schizopolis
# Shiloh
#  TheWar at Home
# Rough Magic
# Trial and Error
# Buddy
# Con Air
# Late Bloomers
#  ThePillow Book
# To Have or Not (En avoir (ou pas))
# Speed 2: Cruise Control
# Squeeze
# Sudden Manhattan
# Wedding Bell Blues
# Batman & Robin
# Dream With the Fishes
# For Roseanna (Roseanna's Grave)
# Head Above Water
# Hercules
# The Last Time I Committed Suicide
# MURDER and murder
# My Best Friend's Wedding
# Tetsuo II: Body Hammer
# When the Cat's Away (Chacun cherche son chat)
# Contempt (Mépris Le)
# Face/Off
# Fall
# Gabbeh
# Mondo
#  TheInnocent Sleep
# For Ever Mozart
# Men in Black (a.k.a. MIB)
# Out to Sea
# Wild America
# Simple Wish A
# Contact
# Love Serenade
# G.I. Jane
# Conan the Barbarian
# George of the Jungle
# Event Horizon
# Spawn
# Air Bud
# Picture Perfect
# In the Company of Men
# Free Willy 3: The Rescue
# Career Girls
# Conspiracy Theory
# Desperate Measures
# Steel
# She's So Lovely
# Hoodlum
# Leave It to Beaver
# Mimic
# Money Talks
# Excess Baggage
# Kull the Conqueror
# Air Force One
# 187 (One Eight Seven)
#  TheHunt for Red October
# My Own Private Idaho
# Kiss Me Guido
# Star Maps
# In & Out
#  TheEdge
#  ThePeacemaker
# L.A. Confidential
# Seven Years in Tibet
# Kiss the Girls
# Soul Food
# Kicked in the Head
# Wishmaster
# Thousand Acres A
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
dataset_test_sql.title[10]
# Out:
# 'American President  The'

# %% [markdown]
# # - - - - - - - - -  - - - - - - - - - - - - - - - - - -- - - - - - - - - - - - - - - - - -

# %% [markdown]
# ##### Step 3: Clean the plot summary - 26.01.2020

# %%
dataset['plot'] = dataset['plot'].apply(lambda x: x.strip())

dataset['plot'] = dataset['plot'].apply(lambda x: x.replace(',', ''))

dataset['plot'] = dataset['plot'].apply(lambda x: x.replace('.', ''))

dataset['plot'] = dataset['plot'].apply(lambda x: x.replace('?', ''))

dataset['plot'] = dataset['plot'].apply(lambda x: x.replace('!', ''))

dataset['plot'] = dataset['plot'].apply(lambda x: x.replace('\n                    See full summary\xa0»', ''))

dataset['plot'] = dataset['plot'].apply(lambda x: x.rstrip())

# %%
dataset['plot'].iloc[-1]
# Out:
# 'Story of a young woman journalist who becomes enmeshed in the politics of the annexation of Morrocco from Algeria at the turn of the twentieth century The focus is on her hardships because'

# %% [markdown]
# # - - - - - - - - -  - - - - - - - - - - - - - - - - - -- - - - - - - - - - - - - - - - - -

# %% [markdown]
# ##### Step 4: Remove empty summaries - 26.01.2020

# %%
len(dataset[dataset['plot'] == 'Add a Plot »'])
# Out:
# 176

# %%
dataset.shape
# Out:
# (49393, 10)

# %%
dataset = dataset[dataset['plot'] != 'Add a Plot »']

dataset.shape
# Out:
# (49217, 10)

# %%
# Fix it with Jack

# def clean_plot_summary(plot):
#     for ch in ['\\','...','`','*','_','{','}','[',']','(',')','>','#','+','-','.','!','$','\'','?','/',"'s","\n                    See full summary\xa0»"]:
#         if ch in plot:
#             plot = plot.replace(ch, '\\'+ch)
#             return plot
#         else:
#             return plot

# %% [markdown]
# # - - - - - - - - -  - - - - - - - - - - - - - - - - - -- - - - - - - - - - - - - - - - - -

# %% [markdown]
# ##### Step 5: Clean the similar movies (based on the similar actors they have) - 29.10.2019

# %%
# dataset['Actors'] = dataset['Actors'].apply(lambda x: ', '.join(x)) old

# %%
# dataset['Actors'] = dataset['Actors'].apply(lambda x: x.replace('-', ' ')) old replacement

# %%
dataset[dataset['title'].str.contains('Avatar')]

# I don't have duplicate movies since the dataset is a generic one from MovieLens
# Out:
#         title                       genres  rating  \
# 14449  Avatar  [Action, Adventure, Sci-Fi]    3.65
#
#                                    imdb_url  \
# 14449  http://www.imdb.com/title/tt0499549/
#
#                                              reviews_url  \
# 14449  http://www.imdb.com/title/tt0499549/reviews?sp...
#
#                                                   actors  \
# 14449  [Sam Worthington, Zoe Saldana, Sigourney Weave...
#
#                                                     plot imdb_rating  \
# 14449  A paraplegic Marine dispatched to the moon Pan...         7.8
#
#             director                                            reviews
# 14449  James Cameron  [Well, I just saw Avatar this morning, one of ...

# %%
# dataset_duplicated = dataset

# dataset_duplicated[dataset_duplicated.duplicated(['Actors'], keep='last')] old

# %%
# dataset = dataset.drop_duplicates('Actors', keep='first') old

# %%
# dataset[dataset['title'].str.contains("Mask")]

# %% [markdown]
# **Comment:** The dataset does not have any duplicate movie title.

# %% [markdown]
# # - - - - - - - - -  - - - - - - - - - - - - - - - - - -- - - - - - - - - - - - - - - - - -

# %% [markdown]
# ##### Step 6: Create the positive/negative column - 26.01.2020

# %%
dataset['sentiment_value'] = dataset['rating']

dataset['sentiment_value'].loc[dataset.rating >=3] = 1

dataset['sentiment_value'].loc[dataset.rating <3] = 0
# Out:
# c:\users\spano\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
dataset.tail()
# Out:
#                             title                       genres  rating  \
# 49387              Dad on the run                     [Comedy]     3.0
# 49388        Üç Harfliler: Beddua                     [Horror]     1.0
# 49390               Tempting Fate       [Drama, Sci-Fi, Sport]     3.0
# 49391  Spring Night, Summer Night                      [Drama]     3.5
# 49392          Isabelle Eberhardt  [Biography, Drama, History]     3.0
#
#                                    imdb_url  \
# 49387  http://www.imdb.com/title/tt0224807/
# 49388  http://www.imdb.com/title/tt7738930/
# 49390  http://www.imdb.com/title/tt0137156/
# 49391  http://www.imdb.com/title/tt0247527/
# 49392  http://www.imdb.com/title/tt0102130/
#
#                                              reviews_url  \
# 49387  http://www.imdb.com/title/tt0224807/reviews?sp...
# 49388  http://www.imdb.com/title/tt7738930/reviews?sp...
# 49390  http://www.imdb.com/title/tt0137156/reviews?sp...
# 49391  http://www.imdb.com/title/tt0247527/reviews?sp...
# 49392  http://www.imdb.com/title/tt0102130/reviews?sp...
#
#                                                   actors  \
# 49387  [Clément Sibony, Rona Hartner, Isaac Sharry, M...
# 49388  [Beyzanur Mete, Esma Soysal, Serife Ünsal, Giz...
# 49390  [Tate Donovan, Abraham Benrubi, Matt Craven, P...
# 49391  [Larue Hall, Ted Heimerdinger, Marjorie Johnso...
# 49392  [Mathilda May, Tchéky Karyo, Peter O'Toole, Ri...
#
#                                                     plot imdb_rating  \
# 49387  Fueled by klezmer and set in the Paris night w...         6.0
# 49388  A little girl called a demon spirit to take he...         7.2
# 49390  A man who is still mourning the death of the w...         6.0
# 49391  Jessica the eldest daughter of a coal miner-tu...         7.0
# 49392  Story of a young woman journalist who becomes ...         5.9
#
#                  director                                            reviews  \
# 49387      Dante Desarthe  [A young father, charged with burying the fore...
# 49388        Alper Mestçi  [I like Alper Mestci movies. This film is like...
# 49390        Peter Werner  [This film was not that bad but it would have ...
# 49391  Joseph L. Anderson  [Here's a film richly deserving of wider expos...
# 49392         Ian Pringle  [The story of the brief life (1877-1904) of Fr...
#
#        sentiment_value
# 49387              1.0
# 49388              0.0
# 49390              1.0
# 49391              1.0
# 49392              1.0

# %% [markdown]
# # - - - - - - - - -  - - - - - - - - - - - - - - - - - -- - - - - - - - - - - - - - - - - -

# %% [markdown]
# ##### Step 7 Create the column Combined Features (29.10.2019)

# %%
# The columns that will be used to create the column "Combined Features"

def combine_features(row):
    return row['title'].lower() + " " + ' '.join(map(str, row['actors'])).lower() + " " + row['director'].lower() + " " + row['plot'].lower() + " " + ' '.join(row['genres']).lower()

# def combine_actors(row):
#     return ', '.join(row['Actors'])

dataset["movie_features"] = dataset.apply(combine_features, axis=1)

# dataset['Actors_Embeddings'] = dataset.apply(combine_actors, axis=1)

# Note: Instead of creating the Actor Embeddings column, vectorize the different name of each actor

# %%
dataset["movie_features"].iloc[0]
# Out:
# "toy story tom hanks tim allen don rickles jim varney wallace shawn john ratzenberger annie potts john morris erik von detten laurie metcalf r. lee ermey sarah freeman penn jillette jack angel spencer aste john lasseter a cowboy doll is profoundly threatened and jealous when a new spaceman figure supplants him as top toy in a boy's room adventure animation children"

# %% [markdown]
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# #### Pickle the dataset (30.10.2019)

# %%
# dataset.to_pickle('dataset_part_2_07112019.pkl') #previous version "dataset_30102019.pkl"

# %%
dataset.to_pickle('D:\\GitHub-Thesis\\58,000 movies\\dataset_part_2_25012020.pkl') #previous versions "dataset_part_2_07112019", "dataset_part_2_24122019"

# %%
dataset.shape
# Out:
# (49217, 12)

# %% [markdown]
# # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %% [markdown]
# #### TO SQL SERVER

# %%
import pyodbc

dataset = pd.read_pickle('D:\\GitHub-Thesis\\58,000 movies\\dataset_part_2_25012020.pkl')

# dataset = dataset.reset_index(drop=True)

dataset.head()
# Out:
#                          title                            genres  rating  \
# 0                    Toy Story  [Adventure, Animation, Children]    3.89
# 1                      Jumanji    [Adventure, Children, Fantasy]    3.25
# 2             Grumpier Old Men                 [Comedy, Romance]    3.17
# 3            Waiting to Exhale          [Comedy, Drama, Romance]    2.87
# 4  Father of the Bride Part II                          [Comedy]    3.08
#
#                                imdb_url  \
# 0  http://www.imdb.com/title/tt0114709/
# 1  http://www.imdb.com/title/tt0113497/
# 2  http://www.imdb.com/title/tt0113228/
# 3  http://www.imdb.com/title/tt0114885/
# 4  http://www.imdb.com/title/tt0113041/
#
#                                          reviews_url  \
# 0  http://www.imdb.com/title/tt0114709/reviews?sp...
# 1  http://www.imdb.com/title/tt0113497/reviews?sp...
# 2  http://www.imdb.com/title/tt0113228/reviews?sp...
# 3  http://www.imdb.com/title/tt0114885/reviews?sp...
# 4  http://www.imdb.com/title/tt0113041/reviews?sp...
#
#                                               actors  \
# 0  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2  [Walter Matthau, Jack Lemmon, Sophia Loren, An...
# 3  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4  [Steve Martin, Diane Keaton, Martin Short, Kim...
#
#                                                 plot imdb_rating  \
# 0  A cowboy doll is profoundly threatened and jea...         8.3
# 1  When two kids find and play a magical board ga...         7.0
# 2  John and Max resolve to save their beloved bai...         6.7
# 3  Based on Terry McMillan's novel this film foll...         5.9
# 4  George Banks must deal not only with the pregn...         6.0
#
#           director                                            reviews  \
# 0    John Lasseter  [Andy's toys live a reasonable life of fun and...
# 1     Joe Johnston  [The smash hit 1995 film Jumanji- based on the...
# 2    Howard Deutch  [Sequels are rarely half as good as the origin...
# 3  Forest Whitaker  [I read some of the other comments comcerning ...
# 4    Charles Shyer  [I enjoyed this film, as I did Father of the B...
#
#    sentiment_value                                     movie_features
# 0              1.0  toy story tom hanks tim allen don rickles jim ...
# 1              1.0  jumanji robin williams jonathan hyde kirsten d...
# 2              1.0  grumpier old men walter matthau jack lemmon so...
# 3              0.0  waiting to exhale whitney houston angela basse...
# 4              1.0  father of the bride part ii steve martin diane...

# %%
#dataset_test_sql = dataset.iloc[0:20]

# %%
dataset[dataset.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [title, genres, rating, imdb_url, reviews_url, actors, plot, imdb_rating, director, reviews, sentiment_value, movie_features]
# Index: []

# %%
dataset.isnull().sum()
# Out:
# title              0
# genres             0
# rating             0
# imdb_url           0
# reviews_url        0
# actors             0
# plot               0
# imdb_rating        0
# director           0
# reviews            0
# sentiment_value    0
# movie_features     0
# dtype: int64

# %%
# MOVIE CONTENT TO SQL TABLE

connStr = pyodbc.connect("DRIVER={SQL Server Native Client 11.0};" #SQL Server Native Client 11.0, #{ODBC Driver 17 for SQL Server}
                         "SERVER=LAPTOP-IFTEP7AL;"
                         "DATABASE=Movies_Dataset;"
                         "Trusted_Connection=Yes")

cursor = connStr.cursor()
 
delete_table =  """           
                        IF [Movies_Dataset].[dbo].TableExists('table_movies') = 1
                             DELETE FROM table_movies
                """

cursor.execute(delete_table)

insert_values = """
                        EXEC [Movies_Dataset].[dbo].[store_movies] @Movie_Title = ?, @IMDB_Rating = ?, @Director = ?, @Plot_Summary = ?, 
                        
                        @IMDB_Url = ?, @Reviews_Url = ?, @MovieLens_User_Rating = ?, @Sentiment_value = ?;
                """

for index, row in dataset.iterrows():

    params = (row['title'], row['imdb_rating'], row['director'], row['plot'], row['imdb_url'], row['reviews_url'], row['rating'], row['sentiment_value'])
    
    cursor.execute(insert_values, params)

connStr.commit()

cursor.close()

connStr.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-151-54bcf9acd1b5> in <module>
#      25     params = (row['title'], row['imdb_rating'], row['director'], row['plot'], row['imdb_url'], row['reviews_url'], row['rating'], row['sentiment_value'])
#      26
# ---> 27     cursor.execute(insert_values, params)
#      28
#      29 connStr.commit()
#
# ProgrammingError: ('42000', '[42000] [Microsoft][SQL Server Native Client 11.0][SQL Server]Error converting data type float to numeric. (8114) (SQLExecDirectW)')

# %%
# ACTORS TO SQL TABLE

column_actors = dataset.loc[:, ['title', 'actors']]

column_actors.shape

s = column_actors.apply(lambda x: pd.Series(x['actors']), axis=1).stack().reset_index(level=1, drop=True)

s.name = 'actors'

actor_names = column_actors.drop('actors', axis=1).join(s)

actor_names['actors'] = pd.Series(actor_names['actors'], dtype=object)

print(actor_names.head(15))

print(actor_names.shape)
# Out:
#        title             actors
# 0  Toy Story          Tom Hanks
# 0  Toy Story          Tim Allen
# 0  Toy Story        Don Rickles
# 0  Toy Story         Jim Varney
# 0  Toy Story      Wallace Shawn
# 0  Toy Story  John Ratzenberger
# 0  Toy Story        Annie Potts
# 0  Toy Story        John Morris
# 0  Toy Story    Erik von Detten
# 0  Toy Story     Laurie Metcalf
# 0  Toy Story       R. Lee Ermey
# 0  Toy Story      Sarah Freeman
# 0  Toy Story      Penn Jillette
# 0  Toy Story         Jack Angel
# 0  Toy Story       Spencer Aste
# (656454, 2)

# %%
connStr = pyodbc.connect("DRIVER={SQL Server Native Client 11.0};"
                         "SERVER=LAPTOP-IFTEP7AL;"
                         "DATABASE=Movies_Dataset;"
                         "Trusted_Connection=yes")

cursor = connStr.cursor()
 
delete_table =  """           
                        IF dbo.TableExists('table_actors') = 1
                             DELETE FROM table_actors      
                """

insert_values = """ 
                        EXEC [dbo].[store_actors] @Movie_Title = ?, @Actors = ?;
                """   

cursor.execute(delete_table)

for index, row in actor_names.iterrows():

    params = (row['title'], row['actors'])
    cursor.execute(insert_values, params)

connStr.commit()

cursor.close()

connStr.close()

# %%
# GENRES TO SQL TABLE

column_genres = dataset.loc[:, ['title', 'genres']]

s = column_genres.apply(lambda x: pd.Series(x['genres']), axis=1).stack().reset_index(level=1, drop=True)

s.name = 'genres'

genres = column_genres.drop('genres', axis=1).join(s)

genres['genres'] = pd.Series(genres['genres'], dtype=object)

genres.head(15)
# Out:
#                          title     genres
# 0                    Toy Story  Adventure
# 0                    Toy Story  Animation
# 0                    Toy Story   Children
# 1                      Jumanji  Adventure
# 1                      Jumanji   Children
# 1                      Jumanji    Fantasy
# 2             Grumpier Old Men     Comedy
# 2             Grumpier Old Men    Romance
# 3            Waiting to Exhale     Comedy
# 3            Waiting to Exhale      Drama
# 3            Waiting to Exhale    Romance
# 4  Father of the Bride Part II     Comedy
# 5                         Heat     Action
# 5                         Heat      Crime
# 5                         Heat   Thriller

# %%
connStr = pyodbc.connect("DRIVER={SQL Server Native Client 11.0};"
                         "SERVER=LAPTOP-IFTEP7AL;"
                         "DATABASE=Movies_Dataset;"
                         "Trusted_Connection=yes")

cursor = connStr.cursor()
 
delete_table =  """           
                        IF dbo.TableExists('table_genres') = 1
                             DELETE FROM table_genres     
                """

insert_values = """ 
                        EXEC [dbo].[store_genres] @Movie_Title = ?, @Genres = ?;
                """   

cursor.execute(delete_table)

for index, row in genres.iterrows():

    params = (row['title'], row['genres'])
    
    cursor.execute(insert_values, params)

connStr.commit()

cursor.close()

connStr.close()

# %%
# REVIEWS TO SQL TABLE

column_reviews = dataset.loc[:, ['title', 'reviews']]

s = column_reviews.apply(lambda x: pd.Series(x['reviews']), axis=1).stack().reset_index(level=1, drop=True)

s.name = 'reviews'

reviews = column_reviews.drop('reviews', axis=1).join(s)

reviews['reviews'] = pd.Series(reviews['reviews'], dtype=object)

reviews.head(15)
# Out:
#        title                                            reviews
# 0  Toy Story  Andy's toys live a reasonable life of fun and ...
# 0  Toy Story  I am a big fan of the animated movies coming f...
# 0  Toy Story  This is a very clever animated story that was ...
# 0  Toy Story  Y'know, I always suspected that my toys were c...
# 0  Toy Story  Toy Story is the film that started Pixar Anima...
# 0  Toy Story  Toy Story is a sheer delight to view on the sc...
# 0  Toy Story  Toy Story is not only the best Disney film bec...
# 0  Toy Story  Though I am not a big fan of computer animatio...
# 0  Toy Story  Just in case you were also wondering what happ...
# 0  Toy Story  Toy story was a fun, imaginative renewal of th...
# 0  Toy Story  Disney and Pixar studios team up and brought u...
# 0  Toy Story  I'm 19, going on 20 in six days. I don't need ...
# 0  Toy Story  What a wonderful integration of classic toys a...
# 0  Toy Story  When Toy Story came, in 1995,I was 9 years old...
# 0  Toy Story  A wonderfully sculpted piece of filmmaking. It...

# %%
connStr = pyodbc.connect("DRIVER={SQL Server Native Client 11.0};"
                         "SERVER=LAPTOP-IFTEP7AL;"
                         "DATABASE=Movies_Dataset;"
                         "Trusted_Connection=yes")

cursor = connStr.cursor()
 
delete_table =  """           
                        IF dbo.TableExists('table_reviews') = 1
                             DELETE FROM table_reviews      
                """

insert_values = """ 
                        EXEC [dbo].[store_reviews] @Movie_Title = ?, @Reviews = ?;
                """   

cursor.execute(delete_table)

for index, row in reviews.iterrows():

    params = (row['title'], row['reviews'])
    cursor.execute(insert_values, params)

connStr.commit()

cursor.close()

connStr.close()

# %% [markdown]
# #### End of part 2 (Transforming the columns of the final dataset)
